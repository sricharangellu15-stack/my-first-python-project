# %% [markdown]
# <a href="https://colab.research.google.com/github/sricharangellu15-stack/my-first-python-project/blob/main/My_First_Script.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
print("This is my first coding class.")
# Out:
# This is my first coding class.

# %% [markdown]
# This is my first python class
